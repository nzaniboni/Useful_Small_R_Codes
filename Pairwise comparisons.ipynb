# %% [markdown]
# ### Pairwise comparisons

# %%
#Ways to visualize pairwise comparisons

# %%
#pairs
pairs(iris[1:4])
# Out:
# plot without title

# %%
#pairs.panels
library(psych)
pairs.panels(iris[1:4])
# Out:
# plot without title

# %%
#ggpairs 
library("ggplot2")  
library("GGally")      
ggpairs(iris[1:4])
# Out:
# plot without title
